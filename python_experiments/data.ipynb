# %%
import numpy as np
import tensorflow as tf
import scipy.io as io

label_dict = {
    'N':0,
    'A':1,
    'O':2,
    '~':3
}

data = []
label = []
lens = []

annotations = open('./training2017/REFERENCE.csv', 'r').read().splitlines()
for line in annotations:
    fname, label_str = line.split(',')
    
    x = io.loadmat('./training2017/'+fname+'.mat')['val'].squeeze()
    data.append(x)
    
    y = label_dict[label_str]
    label.append(y)
    
    lens.append(len(x))
    
assert(len(label) == len(data) == len(lens))
data_size = len(data)

# No problem with different lengths
# Using np.array because slice indexing does not copy the data
# While native python slicing does
data = np.array(data)
label = np.array(label)
lens = np.array(lens)

# %%
#a = list(range(10))
a = np.arange(10)
b = a[3:5]
b[0] = 10
a
# Out:
# array([ 0,  1,  2, 10,  4,  5,  6,  7,  8,  9])

# %%
def shuffle():
    global data
    global label
    global lens
    p = np.random.permutation(data_size)
    # Using fancy indexing for Unison Shuffle
    data = data[p]
    label = label[p]
    lens = lens[p]
    

def batch_pool(batch_size=4, num_epochs=10, random=True):
    n = batch_size
    if random:
        shuffle()
    for _ in range(num_epochs):
        for i in range(0, data_size, batch_size):
            yield data[i:i+n], label[i:i+n], lens[i:i+n]

# %%
batch_feeder = batch_pool()
list(batch_feeder)
# Out:
# [(array([array([301, 325, 342, ..., 119,  66,  14], dtype=int16),
#          array([1427, 1641, 1853, ...,  -22,  -15,   -8], dtype=int16),
#          array([202, 249, 307, ..., 289, 284, 207], dtype=int16),
#          array([ 73,  96, 123, ..., -97, -62, -40], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([227, 270, 323, ...,  -4,  -8, -10], dtype=int16),
#          array([ 18,  20,  28, ..., -38, -36, -34], dtype=int16),
#          array([38, 53, 64, ..., 42, 39, 36], dtype=int16),
#          array([ 10,  12,  13, ..., -21, -17, -13], dtype=int16)], dtype=object),
#   array([0, 0, 0, 1]),
#   array([9000, 9000, 4272, 9000])),
#  (array([array([-111, -134, -150, ...,  -35,  -28,  -16], dtype=int16),
#          array([260, 302, 352, ..., -33, -30, -27], dtype=int16),
#          array([  -85,  -108,  -144, ..., -1190,  -961,  -751], dtype=int16),
#          array([-273, -327, -384, ...,  -60,  -46,  -31], dtype=int16)], dtype=object),
#   array([0, 0, 3, 2]),
#   array([9000, 9000, 3138, 8534])),
#  (array([array([100, 120, 134, ...,  39,  32,  29], dtype=int16),
#          array([ 13,  15,  16, ..., -69, -64, -59], dtype=int16),
#          array([-1441, -1669, -1888, ...,    73,    61,    37], dtype=int16),
#          array([-21, -24, -29, ...,  71,  53,  39], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([ -64,  -85, -106, ...,  -31,  -14,    1], dtype=int16),
#          array([10, 12, 14, ...,  2,  8, 17], dtype=int16),
#          array([-59, -83, -96, ..., -82, -66, -41], dtype=int16),
#          array([-368, -456, -548, ...,  -85,  -65,  -46], dtype=int16)], dtype=object),
#   array([0, 0, 0, 1]),
#   array([18000,  9000,  9000,  9000])),
#  (array([array([-196, -231, -271, ...,  -21,  -11,   -1], dtype=int16),
#          array([-359, -436, -509, ...,  -13,   -1,    7], dtype=int16),
#          array([-346, -415, -486, ...,   99,   71,   51], dtype=int16),
#          array([-535, -646, -757, ...,  -46,  -40,  -34], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([ 9000,  9000,  9000, 18000])),
#  (array([array([-53, -36,  23, ..., -72, -59, -49], dtype=int16),
#          array([-489, -588, -687, ...,  -68,  -50,  -30], dtype=int16),
#          array([-234, -280, -328, ...,   31,   26,   20], dtype=int16),
#          array([-148, -185, -224, ...,  209,  141,   56], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([474, 568, 659, ..., 172, 103,  14], dtype=int16),
#          array([-10,  -9,  -8, ..., -29, -25, -21], dtype=int16),
#          array([-129, -119, -108, ...,  -17,  -13,  -12], dtype=int16),
#          array([293, 346, 399, ...,  51,  52,  47], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([-521, -626, -728, ...,   45,   34,   22], dtype=int16),
#          array([716, 850, 983, ...,  61,  47,  29], dtype=int16),
#          array([154, 188, 224, ..., -19,  11,  13], dtype=int16),
#          array([-14, -14, -14, ..., 710, 592, 413], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([140, 169, 198, ...,   0,  -1,  -2], dtype=int16),
#          array([203, 253, 303, ...,  89,  76,  54], dtype=int16),
#          array([-377, -446, -520, ...,  -46,  -39,  -31], dtype=int16),
#          array([-469, -578, -695, ...,  -29,  -32,  -35], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 9000, 4050, 9000])),
#  (array([array([ -34,  -39,  -46, ..., -102,  -81,  -62], dtype=int16),
#          array([-126, -154, -185, ...,   26,   26,   25], dtype=int16),
#          array([ 32,  40,  52, ..., -22, -13,  -3], dtype=int16),
#          array([  61,   86,  116, ...,  -32,  -87, -116], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([13450, 18000,  9000, 18000])),
#  (array([array([ -912, -1087, -1270, ...,    12,    10,     8], dtype=int16),
#          array([  3,   1,   0, ..., -38, -34, -29], dtype=int16),
#          array([-63, -71, -79, ...,   0,   4,   6], dtype=int16),
#          array([-575, -691, -808, ...,   10,   11,   12], dtype=int16)], dtype=object),
#   array([2, 0, 1, 0]),
#   array([18000,  9000,  9000,  9000])),
#  (array([array([-130, -156, -186, ..., -143, -127, -122], dtype=int16),
#          array([362, 443, 537, ..., 817, 633, 402], dtype=int16),
#          array([ -92, -103, -113, ...,  -45,  -40,  -33], dtype=int16),
#          array([31, 31, 27, ..., 45, 45, 44], dtype=int16)], dtype=object),
#   array([0, 2, 0, 1]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 16,  21,  28, ..., -42, -34, -23], dtype=int16),
#          array([-12, -13, -15, ...,  31,  29,  28], dtype=int16),
#          array([ 5,  6,  8, ..., 39, 27, 16], dtype=int16),
#          array([ -12,  -14,  -21, ..., -267, -277, -299], dtype=int16)], dtype=object),
#   array([1, 1, 0, 0]),
#   array([9000, 9000, 3868, 5076])),
#  (array([array([205, 252, 311, ...,  29,  22,  11], dtype=int16),
#          array([ 95, 124, 154, ..., -78, -55, -43], dtype=int16),
#          array([-149, -187, -222, ...,    1,    1,    1], dtype=int16),
#          array([-199, -246, -275, ...,    4,    6,    9], dtype=int16)], dtype=object),
#   array([2, 0, 2, 0]),
#   array([ 9000,  8062,  9000, 10636])),
#  (array([array([103, 123, 148, ...,   3,   2,   1], dtype=int16),
#          array([ 23,  26,  32, ..., -16, -15, -15], dtype=int16),
#          array([-40, -57, -69, ...,  10,   9,  10], dtype=int16),
#          array([ -6,  -7,  -8, ...,   5, -11, -13], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 174,  211,  249, ..., -106,  -76,  -52], dtype=int16),
#          array([  1,  33,  64, ..., -18, -12,  -5], dtype=int16),
#          array([-53, -55, -57, ..., 131, 143, 157], dtype=int16),
#          array([-282, -343, -405, ...,  117,  128,  133], dtype=int16)], dtype=object),
#   array([2, 1, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([376, 458, 537, ..., -98, -90, -77], dtype=int16),
#          array([489, 587, 689, ...,  22,  20,  18], dtype=int16),
#          array([-17, -18, -19, ...,  26,  14,  11], dtype=int16),
#          array([17, 18, 19, ..., 11,  7,  5], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-2023, -2434, -2866, ...,  -283,  -229,  -177], dtype=int16),
#          array([-65, -82, -97, ..., -17,  -6,   1], dtype=int16),
#          array([163, 199, 235, ...,  -9,  -8,  -7], dtype=int16),
#          array([ 115,  141,  162, ..., -301, -219, -123], dtype=int16)], dtype=object),
#   array([1, 0, 0, 0]),
#   array([9000, 9000, 9000, 4220])),
#  (array([array([440, 525, 606, ...,  43,  40,  35], dtype=int16),
#          array([-22, -23, -24, ..., -18, -13,  -9], dtype=int16),
#          array([-1255, -1488, -1745, ...,    14,     9,     8], dtype=int16),
#          array([-25, -42, -56, ..., -79, -46, -19], dtype=int16)], dtype=object),
#   array([0, 1, 0, 0]),
#   array([3260, 3324, 9000, 9000])),
#  (array([array([-104, -133, -164, ...,   48,   45,   44], dtype=int16),
#          array([274, 305, 341, ..., -67, -51, -36], dtype=int16),
#          array([-471, -572, -664, ...,  -58,  -29,  -20], dtype=int16),
#          array([222, 252, 281, ..., -56, -39, -24], dtype=int16)], dtype=object),
#   array([2, 0, 0, 1]),
#   array([9000, 3600, 9000, 9000])),
#  (array([array([-148, -180, -214, ...,    0,    0,    1], dtype=int16),
#          array([ 64,  81,  93, ..., 117, 129,  96], dtype=int16),
#          array([133, 169, 207, ..., -91, -81, -72], dtype=int16),
#          array([-384, -405, -432, ...,   82,   76,   65], dtype=int16)], dtype=object),
#   array([1, 0, 2, 2]),
#   array([ 9000, 12700,  9000,  9000])),
#  (array([array([101, 132, 164, ...,   0,   7,  15], dtype=int16),
#          array([ 47,  52,  44, ..., 125, 107,  89], dtype=int16),
#          array([-173, -221, -268, ...,  239,  223,  179], dtype=int16),
#          array([-561, -683, -805, ...,  -43,  -43,  -43], dtype=int16)], dtype=object),
#   array([2, 0, 2, 2]),
#   array([10848,  9000, 11520,  9000])),
#  (array([array([-336, -402, -467, ...,    9,   20,   30], dtype=int16),
#          array([423, 514, 524, ...,  86,  72,  51], dtype=int16),
#          array([-19, -21, -26, ...,  84,  71,  58], dtype=int16),
#          array([313, 378, 444, ...,  35,  37,  38], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([ 9000, 14630, 18000,  9000])),
#  (array([array([-123, -151, -190, ...,  -78,  -71,  -63], dtype=int16),
#          array([220, 295, 387, ...,  45,  30,  13], dtype=int16),
#          array([-30, -46, -55, ..., 113, 105,  95], dtype=int16),
#          array([173, 191, 206, ...,  68,  73,  79], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 9000, 3572])),
#  (array([array([-59, -58, -58, ..., 113, 106,  93], dtype=int16),
#          array([-21, -20, -20, ...,  42,  45,  49], dtype=int16),
#          array([ -66,  -77,  -84, ..., -136, -103,  -60], dtype=int16),
#          array([-234, -263, -312, ...,   15,   15,   16], dtype=int16)], dtype=object),
#   array([0, 2, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([120, 151, 188, ...,  24,   4, -28], dtype=int16),
#          array([-241, -355, -469, ...,   20,   18,   17], dtype=int16),
#          array([-12, -14, -16, ...,  39,  41,  42], dtype=int16),
#          array([ 748,  893, 1041, ...,   27,   23,   17], dtype=int16)], dtype=object),
#   array([2, 0, 1, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([217, 257, 298, ..., -51, -46, -39], dtype=int16),
#          array([-73, -49, -21, ...,   1,   1,   1], dtype=int16),
#          array([-1971, -2318, -2641, ...,    26,    22,    20], dtype=int16),
#          array([644, 762, 879, ..., -30, -21, -19], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([258, 294, 337, ..., -50, -34, -22], dtype=int16),
#          array([ 59,  80,  98, ..., -18, -10,  -7], dtype=int16),
#          array([-394, -475, -556, ...,  -36,  -31,  -24], dtype=int16),
#          array([708, 844, 979, ..., -42, -42, -41], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([  8,   7,   6, ..., -43, -31, -24], dtype=int16),
#          array([ 417,  496,  572, ..., -320, -241, -155], dtype=int16),
#          array([-21, -29, -53, ..., -61, -52, -45], dtype=int16),
#          array([29, 53, 71, ..., 76, 62, 48], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([9000, 8694, 9000, 9000])),
#  (array([array([-589, -698, -858, ...,   67,   52,   21], dtype=int16),
#          array([-504, -633, -767, ...,  -94,  -75,  -54], dtype=int16),
#          array([ 164,  195,  226, ..., -179, -143, -103], dtype=int16),
#          array([215, 245, 275, ...,   6,   4,   3], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9620, 9000])),
#  (array([array([ -80,  -94, -103, ...,   11,    5,  -15], dtype=int16),
#          array([ 35,  26,  16, ..., 106, 117, 127], dtype=int16),
#          array([  4,   5,   5, ..., -41, -35, -26], dtype=int16),
#          array([-9, -6, -2, ...,  5,  4,  7], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([586, 702, 826, ...,  -9,  -6,  -4], dtype=int16),
#          array([-101, -122, -133, ...,    4,    4,    4], dtype=int16),
#          array([470, 666, 868, ..., -81, -67, -58], dtype=int16),
#          array([20, 20, 20, ..., -4, -5, -6], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([ 9000,  9000, 14006,  9000])),
#  (array([array([ 68,  13, -32, ..., 142, 139, 136], dtype=int16),
#          array([ -906, -1261, -1705, ...,    79,    73,    62], dtype=int16),
#          array([608, 734, 872, ...,  -3,  -2,  -7], dtype=int16),
#          array([-10, -10, -10, ..., -52, -52, -51], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -83,  -94, -101, ...,  -52,  -46,  -38], dtype=int16),
#          array([-214, -282, -355, ...,  -67,  -56,  -47], dtype=int16),
#          array([-22, -27, -33, ...,  -7,  46,  52], dtype=int16),
#          array([167, 199, 230, ...,  -1,   0,   1], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 40,  64,  77, ..., -72, -52, -46], dtype=int16),
#          array([-19, -24, -43, ...,  20,  15,  12], dtype=int16),
#          array([  0,  -1,  -2, ..., 247, 196, 149], dtype=int16),
#          array([149, 177, 202, ..., -44, -14,   9], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 758,  902, 1055, ...,   31,   29,   26], dtype=int16),
#          array([-101, -133, -166, ...,  -22,  -10,   -6], dtype=int16),
#          array([ -958, -1122, -1287, ...,   -17,   -19,   -20], dtype=int16),
#          array([-2, -3, -4, ..., 17, 10,  1], dtype=int16)], dtype=object),
#   array([2, 0, 0, 1]),
#   array([ 9000, 11234,  9000, 18000])),
#  (array([array([ 44,  44,  44, ..., 564, 399, 240], dtype=int16),
#          array([179, 217, 253, ..., 159, 130, 101], dtype=int16),
#          array([422, 506, 585, ..., -20, -17, -15], dtype=int16),
#          array([-26, -30, -46, ...,  21,  19,  18], dtype=int16)], dtype=object),
#   array([2, 2, 0, 2]),
#   array([ 9000, 11994,  9000,  9000])),
#  (array([array([ -98, -117, -136, ...,  -72,  -58,  -45], dtype=int16),
#          array([275, 342, 405, ...,  34,  32,  31], dtype=int16),
#          array([-19, -17,  -6, ..., 207, 149,  90], dtype=int16),
#          array([285, 345, 410, ...,  29,  28,  27], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([9000, 9000, 9138, 7328])),
#  (array([array([-102, -111, -117, ...,   18,   17,   16], dtype=int16),
#          array([ 60,  81, 108, ...,   7,   3,   0], dtype=int16),
#          array([ -744,  -895, -1053, ...,  -141,  -162,  -178], dtype=int16),
#          array([39, 53, 75, ..., 33, 39, 45], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([ 9000,  9000,  9000, 18000])),
#  (array([array([18, 20, 22, ..., 85, 61, 38], dtype=int16),
#          array([-18, -22, -28, ...,  23,  20,  18], dtype=int16),
#          array([1550, 1911, 2281, ...,  107,   80,   50], dtype=int16),
#          array([18, 19, 20, ...,  3,  4,  5], dtype=int16)], dtype=object),
#   array([0, 0, 2, 1]),
#   array([3912, 9000, 9000, 9000])),
#  (array([array([-24, -26, -33, ...,  29,  19,  11], dtype=int16),
#          array([52, 60, 59, ..., 69, 67, 66], dtype=int16),
#          array([-30, -42, -57, ..., -19, -15, -11], dtype=int16),
#          array([-242, -291, -346, ...,  -17,   -5,    8], dtype=int16)], dtype=object),
#   array([1, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-273, -328, -386, ...,  114,   80,   60], dtype=int16),
#          array([711, 842, 981, ...,  54,  40,  27], dtype=int16),
#          array([129, 151, 177, ...,  12,  11,  11], dtype=int16),
#          array([254, 276, 288, ...,   4, -10,  -9], dtype=int16)], dtype=object),
#   array([0, 2, 2, 2]),
#   array([ 9000,  7214,  9000, 18000])),
#  (array([array([-1002, -1192, -1384, ...,   100,    70,    39], dtype=int16),
#          array([ 95, 123, 153, ...,  56,  42,  23], dtype=int16),
#          array([ -78, -127, -174, ..., -167, -116,  -39], dtype=int16),
#          array([-119, -145, -177, ...,   26,   25,   24], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([ 9000,  9000,  9000, 10404])),
#  (array([array([227, 316, 422, ...,  14,   6,   1], dtype=int16),
#          array([1762, 2093, 2434, ...,   39,   27,   15], dtype=int16),
#          array([-35, -39, -44, ..., -52, -47, -37], dtype=int16),
#          array([ 66,  78,  90, ..., -26, -21, -17], dtype=int16)], dtype=object),
#   array([1, 0, 0, 0]),
#   array([9000, 9000, 4522, 9000])),
#  (array([array([-427, -514, -604, ...,  -13,  -13,  -13], dtype=int16),
#          array([426, 526, 632, ...,  74,  62,  52], dtype=int16),
#          array([104, 126, 149, ..., -41, -32, -23], dtype=int16),
#          array([-211, -256, -303, ...,  203,  167,  131], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([5866, 9000, 9000, 9000])),
#  (array([array([-67, -78, -86, ..., -99, -91, -80], dtype=int16),
#          array([448, 532, 618, ..., -52, -18,   3], dtype=int16),
#          array([282, 332, 379, ...,   4,  -3, -10], dtype=int16),
#          array([-268, -313, -357, ...,   -5,   -3,   -1], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([ 4504, 18000,  9000,  9000])),
#  (array([array([286, 341, 400, ...,  18,  18,  18], dtype=int16),
#          array([487, 541, 562, ..., -16, -17, -19], dtype=int16),
#          array([156, 205, 235, ..., 139, 105,  71], dtype=int16),
#          array([207, 242, 285, ..., 176, 135,  83], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([10494,  9000,  3296, 18000])),
#  (array([array([-47, -61, -69, ..., -41, -32, -26], dtype=int16),
#          array([ 56,  70,  81, ..., -17, -15, -14], dtype=int16),
#          array([ -4,  -4,  -4, ..., -72, -48, -24], dtype=int16),
#          array([ -28,  -34,  -41, ...,  321,   38, -245], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 9000, 9182])),
#  (array([array([-11, -12, -12, ...,  99,  83,  63], dtype=int16),
#          array([241, 294, 350, ...,  -2,  -3,  -3], dtype=int16),
#          array([-477, -570, -675, ...,   30,   27,   25], dtype=int16),
#          array([-1537, -1836, -2118, ...,   -56,   -25,    -1], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([ 4732, 18000,  9000,  9000])),
#  (array([array([ -97, -126, -156, ...,   60,   51,   42], dtype=int16),
#          array([706, 851, 978, ..., 514, 356, 185], dtype=int16),
#          array([ -857, -1022, -1196, ...,   804,   767,   683], dtype=int16),
#          array([ -83,  -96, -106, ...,   30,   20,   13], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([ 9000, 10370,  9000,  9000])),
#  (array([array([-1413, -1631, -1839, ...,   -50,   -39,   -29], dtype=int16),
#          array([ 20,  28,  55, ..., -12, -11, -10], dtype=int16),
#          array([  1,   0,   0, ..., -28, -27, -25], dtype=int16),
#          array([  -3,   -2,   -2, ...,  -57,  -80, -100], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-113, -139, -167, ..., -203, -133,  -13], dtype=int16),
#          array([216, 262, 309, ...,  99,  71,  44], dtype=int16),
#          array([ 96, 129, 157, ..., -12, -10,  -9], dtype=int16),
#          array([ 65,  81,  95, ..., -76, -56, -40], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([493, 585, 681, ...,   4,   4,   4], dtype=int16),
#          array([  10,   13,   15, ..., -146,  -35,   89], dtype=int16),
#          array([ -90, -118, -144, ...,  -80,  -76,  -70], dtype=int16),
#          array([-253, -298, -346, ...,   87,   70,   41], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([18000,  9000,  9000,  9000])),
#  (array([array([246, 302, 357, ..., -72, -64, -54], dtype=int16),
#          array([-367, -443, -522, ...,  142,   85,   30], dtype=int16),
#          array([-208, -261, -314, ...,   -6,   -5,   -3], dtype=int16),
#          array([742, 857, 978, ..., -84, -74, -57], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([14, 14, 14, ..., 22, 22, 22], dtype=int16),
#          array([249, 292, 341, ...,  30,  35,  40], dtype=int16),
#          array([26, 35, 48, ..., 42, 36, 30], dtype=int16),
#          array([-68, -73, -74, ...,  41,  31,  24], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([4562, 9000, 9000, 8902])),
#  (array([array([  1,   2,  -1, ..., 219, 180, 136], dtype=int16),
#          array([64, 84, 97, ...,  5,  4,  3], dtype=int16),
#          array([-25, -30, -38, ...,  20,  18,  15], dtype=int16),
#          array([ -748,  -895, -1051, ...,   -40,   -36,   -32], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([ 6162,  9000,  4982, 18000])),
#  (array([array([-13, -14, -16, ..., -12, -21, -27], dtype=int16),
#          array([ 846, 1285, 1714, ...,    0,   -1,   -3], dtype=int16),
#          array([-2, -1,  0, ...,  0,  1,  2], dtype=int16),
#          array([-356, -428, -504, ...,   25,   22,   19], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([ 9000, 10380,  9000,  9000])),
#  (array([array([295, 314, 328, ..., -20, -16, -11], dtype=int16),
#          array([-79, -85, -89, ...,  43,  44,  46], dtype=int16),
#          array([256, 301, 346, ..., -15, -13, -12], dtype=int16),
#          array([205, 235, 265, ..., -13, -12, -10], dtype=int16)], dtype=object),
#   array([0, 2, 0, 1]),
#   array([9000, 9938, 9000, 9000])),
#  (array([array([140, 126, 115, ..., 834, 908, 904], dtype=int16),
#          array([632, 658, 728, ...,  32,  79,  76], dtype=int16),
#          array([-342, -411, -479, ...,  -67,  -55,  -36], dtype=int16),
#          array([ -86, -114, -146, ...,  -36,  -28,   -9], dtype=int16)], dtype=object),
#   array([2, 2, 1, 0]),
#   array([9000, 4300, 9000, 9000])),
#  (array([array([-25, -50, -68, ..., -65, -35,  -8], dtype=int16),
#          array([-32, -53, -67, ...,   9,   9,   9], dtype=int16),
#          array([230, 265, 293, ..., -69, -51, -32], dtype=int16),
#          array([-243, -290, -343, ...,   39,   40,   40], dtype=int16)], dtype=object),
#   array([1, 0, 0, 0]),
#   array([ 9000, 14384,  9000, 18000])),
#  (array([array([-31, -41, -50, ...,  -3,  -1,  -1], dtype=int16),
#          array([-247, -298, -349, ...,   69,   62,   52], dtype=int16),
#          array([193, 222, 270, ...,  30,  30,  29], dtype=int16),
#          array([117, 195, 313, ...,  -4,  -3,  -2], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([18000,  9000,  4350, 18000])),
#  (array([array([-542, -650, -771, ...,   29,   27,   26], dtype=int16),
#          array([ 85,  96, 106, ..., -20, -12,  -9], dtype=int16),
#          array([ 97, 115, 128, ..., -73, -64, -47], dtype=int16),
#          array([ 53,  56,  67, ...,   0,  -2, -21], dtype=int16)], dtype=object),
#   array([0, 0, 0, 1]),
#   array([5472, 7640, 9000, 9000])),
#  (array([array([-130, -175, -219, ...,  -14,  -16,  -17], dtype=int16),
#          array([341, 372, 427, ..., -30, -28, -22], dtype=int16),
#          array([-1018, -1222, -1430, ...,   -68,   -66,   -64], dtype=int16),
#          array([165, 198, 243, ...,   9,  10,  11], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([  20,  -91, -262, ...,  -41,  -34,  -23], dtype=int16),
#          array([-44, -54, -60, ...,  34,  30,  26], dtype=int16),
#          array([-12, -14, -16, ...,  51,  51,  51], dtype=int16),
#          array([1345, 1600, 1862, ...,   -8,   -4,   -1], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 6140, 9000])),
#  (array([array([336, 414, 491, ...,  24,  24,  25], dtype=int16),
#          array([-11, -12, -12, ..., -14, -13, -13], dtype=int16),
#          array([ 14,   8,   3, ..., -13, -51, -87], dtype=int16),
#          array([453, 534, 610, ..., 188,  18,  19], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-178, -218, -255, ...,   23,   22,   21], dtype=int16),
#          array([  2,   2,   3, ..., -18, -14, -11], dtype=int16),
#          array([-15, -16, -17, ..., -41, -35, -31], dtype=int16),
#          array([ -87, -117, -141, ...,  -59,  -36,  -11], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 9000, 9818])),
#  (array([array([-1393, -1666, -1940, ...,   -55,   -51,   -42], dtype=int16),
#          array([-156, -173, -178, ...,  128,   96,   66], dtype=int16),
#          array([-407, -471, -494, ...,   29,   23,   21], dtype=int16),
#          array([254, 330, 423, ..., -14, -11,  -9], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 254,  305,  340, ..., -148, -111,  -88], dtype=int16),
#          array([-36, -48, -54, ..., 176, 136,  97], dtype=int16),
#          array([-414, -481, -548, ...,   45,   46,   47], dtype=int16),
#          array([-504, -611, -733, ...,   74,   55,   42], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 2812, 9000, 9000])),
#  (array([array([-21, -43, -63, ..., 296, 181,  59], dtype=int16),
#          array([494, 603, 705, ...,  22,  18,  13], dtype=int16),
#          array([-432, -446, -430, ...,  -18,   -9,   -5], dtype=int16),
#          array([236, 290, 345, ...,  18,  14,   8], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([5898, 9000, 9000, 9000])),
#  (array([array([-19, -40, -60, ..., -20, -18, -17], dtype=int16),
#          array([260, 303, 355, ..., -13,  -6,   1], dtype=int16),
#          array([-120, -148, -175, ...,  162,  145,  135], dtype=int16),
#          array([ 35,  70, 118, ..., -67, -42, -17], dtype=int16)], dtype=object),
#   array([1, 0, 3, 0]),
#   array([7594, 9000, 9000, 9000])),
#  (array([array([153, 187, 208, ..., -11,  -6,  -3], dtype=int16),
#          array([-62, -60, -58, ..., -16, -13, -10], dtype=int16),
#          array([161, 207, 255, ..., 192, 147, 106], dtype=int16),
#          array([-482, -575, -682, ...,    6,    7,    7], dtype=int16)], dtype=object),
#   array([1, 2, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 18,  20,  23, ..., -43, -28, -18], dtype=int16),
#          array([67, 68, 70, ..., 16, 20, 24], dtype=int16),
#          array([-186, -222, -259, ...,  -37,  -27,  -18], dtype=int16),
#          array([ -98, -113, -133, ...,  -18,  -17,  -16], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -24,  -25,  -29, ..., -797, -620, -415], dtype=int16),
#          array([ 22,  45,  70, ..., -20, -19, -17], dtype=int16),
#          array([-234, -289, -344, ...,   12,   18,   23], dtype=int16),
#          array([-2111, -2562, -3029, ...,    -6,    -6,    -6], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([  61,   71,   79, ..., -138,  -29,   93], dtype=int16),
#          array([579, 687, 798, ...,   8,   6,   5], dtype=int16),
#          array([423, 502, 580, ...,  68,  67,  64], dtype=int16),
#          array([142, 170, 205, ...,  88,  75,  60], dtype=int16)], dtype=object),
#   array([2, 1, 0, 0]),
#   array([4568, 9000, 9000, 9000])),
#  (array([array([-398, -488, -580, ...,  -48,  -33,  -17], dtype=int16),
#          array([-47, -57, -67, ...,  -7,  -5,  -3], dtype=int16),
#          array([21, 36, 51, ..., 63, 59, 52], dtype=int16),
#          array([152, 179, 200, ...,   5,   0,  -6], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000,  9000,  4488, 18000])),
#  (array([array([16, 17, 18, ..., 81, 66, 52], dtype=int16),
#          array([512, 624, 746, ...,  11,  11,  12], dtype=int16),
#          array([-166, -192, -213, ...,  -76,  -69,  -58], dtype=int16),
#          array([ 15,  17,  19, ..., -14, -11,  -8], dtype=int16)], dtype=object),
#   array([0, 2, 2, 1]),
#   array([18000,  9000, 18000,  9000])),
#  (array([array([427, 513, 602, ..., -71, -59, -48], dtype=int16),
#          array([289, 306, 329, ...,  15,  12,   9], dtype=int16),
#          array([-16, -16, -15, ...,   1,   1,   2], dtype=int16),
#          array([-393, -495, -578, ..., -106,  -72,  -61], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([9000, 3732, 9000, 9000])),
#  (array([array([ 34,  48,  56, ..., 190, 153, 132], dtype=int16),
#          array([ -79,  -94, -117, ...,  -44,  -38,  -32], dtype=int16),
#          array([ 20,  21,  23, ..., -36, -25, -11], dtype=int16),
#          array([-1140, -1363, -1585, ...,  -459,  -334,  -181], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000,  9000,  9000, 12150])),
#  (array([array([223, 269, 319, ...,   1,   1,   0], dtype=int16),
#          array([   0,    0,   -2, ..., -114,  -97,  -82], dtype=int16),
#          array([-521, -626, -734, ...,   49,    5,  -56], dtype=int16),
#          array([-380, -466, -554, ...,    8,    5,    3], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([18000, 10256,  9000,  9000])),
#  (array([array([-541, -664, -799, ...,  -75,  -65,  -53], dtype=int16),
#          array([110, 128, 140, ..., 150, 124, 100], dtype=int16),
#          array([227, 256, 301, ..., -80, -55, -34], dtype=int16),
#          array([ -933, -1107, -1282, ...,   225,    21,    23], dtype=int16)], dtype=object),
#   array([2, 1, 1, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-520, -624, -714, ...,  120,   76,   34], dtype=int16),
#          array([313, 381, 457, ..., -31, -29, -28], dtype=int16),
#          array([ 623,  744,  870, ..., -121,  -95,  -67], dtype=int16),
#          array([442, 523, 610, ...,  68,  67,  60], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([4468, 9000, 9000, 8968])),
#  (array([array([ -388,  -454,  -522, ..., -2665, -2077, -1332], dtype=int16),
#          array([ 17,  19,  26, ...,  29,  -3, -35], dtype=int16),
#          array([253, 281, 301, ...,  44,  39,  35], dtype=int16),
#          array([-676, -808, -945, ...,  -30,  -32,  -33], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([ 9000, 11646,  9000, 18000])),
#  (array([array([-215, -261, -308, ...,    0,    4,    7], dtype=int16),
#          array([250, 294, 340, ..., 656, 579, 509], dtype=int16),
#          array([-61, -69, -73, ...,  36,  32,  29], dtype=int16),
#          array([-14, -15, -17, ...,  -6,  -5,  -4], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([ 9000,  8670, 10294,  9000])),
#  (array([array([-248, -343, -439, ...,   80,   68,   49], dtype=int16),
#          array([-156, -187, -222, ..., -177, -135,  -99], dtype=int16),
#          array([ -985, -1165, -1340, ...,    44,    41,    35], dtype=int16),
#          array([160, 194, 229, ...,  -5, -10, -14], dtype=int16)], dtype=object),
#   array([0, 2, 0, 1]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-194, -241, -295, ...,  122,  104,   81], dtype=int16),
#          array([-26, -40, -54, ..., 165, 121,  95], dtype=int16),
#          array([683, 798, 917, ..., -46, -45, -44], dtype=int16),
#          array([ 199,  234,  275, ..., -205, -178, -148], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([ 9000,  9000,  9000, 10090])),
#  (array([array([-527, -629, -733, ...,   90,   75,   56], dtype=int16),
#          array([-166, -199, -235, ...,    0,    2,    4], dtype=int16),
#          array([-456, -547, -638, ...,   52,   46,   37], dtype=int16),
#          array([-158, -193, -232, ...,  -44,  -41,  -38], dtype=int16)], dtype=object),
#   array([0, 1, 2, 1]),
#   array([ 9000,  3252, 18000,  9000])),
#  (array([array([  56,   74,   92, ..., -102,  -81,  -58], dtype=int16),
#          array([110, 144, 178, ..., -32, -19,  -5], dtype=int16),
#          array([ 621,  735,  852, ..., -103,  -92,  -81], dtype=int16),
#          array([ 64,  78,  88, ..., -41, -39, -36], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9874, 9000, 9000, 9840])),
#  (array([array([ -58,  -79, -100, ...,   58,  -24,  -13], dtype=int16),
#          array([1254, 1462, 1655, ...,    0,    2,    4], dtype=int16),
#          array([-134, -238, -349, ...,   12,   12,   13], dtype=int16),
#          array([-219, -272, -306, ..., -134, -106,  -79], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([ 23,  24,  24, ..., -96, -97, -90], dtype=int16),
#          array([-14, -16, -18, ..., 145, 115,  88], dtype=int16),
#          array([628, 741, 864, ...,   3,   3,   3], dtype=int16),
#          array([-409, -504, -604, ...,  -76,  -76,  -78], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([11, 11, 12, ..., -1,  0,  2], dtype=int16),
#          array([140, 152, 160, ..., -20, -18, -17], dtype=int16),
#          array([ 945, 1126, 1315, ..., 2170, 1607, 1096], dtype=int16),
#          array([-165, -214, -248, ...,  -86,  -70,  -53], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([18000, 18000,  4494,  9000])),
#  (array([array([ 86, 104, 124, ...,  -1,  -2,  -3], dtype=int16),
#          array([ 28,  36,  44, ...,  -6,  -8, -11], dtype=int16),
#          array([126, 168, 215, ...,  17,  16,  16], dtype=int16),
#          array([1327, 1498, 1637, ...,   -2,   -4,   -6], dtype=int16)], dtype=object),
#   array([2, 0, 2, 2]),
#   array([18000,  9000,  9000,  9000])),
#  (array([array([-107, -130, -147, ..., -114,  -86,  -54], dtype=int16),
#          array([ 74,  90, 107, ..., -48, -43, -38], dtype=int16),
#          array([-65, -80, -94, ...,  39,  35,  29], dtype=int16),
#          array([-29, -26, -23, ..., -37, -39, -41], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([9000, 9000, 4942, 9000])),
#  (array([array([-169, -204, -241, ...,  514,  424,  339], dtype=int16),
#          array([283, 345, 411, ...,  62,  59,  56], dtype=int16),
#          array([107, 128, 155, ..., 456, 400, 271], dtype=int16),
#          array([ 202,  235,  274, ..., -295, -288, -192], dtype=int16)], dtype=object),
#   array([2, 2, 1, 2]),
#   array([9000, 9000, 3178, 9000])),
#  (array([array([  20,   26,   35, ..., -314,  -81,  214], dtype=int16),
#          array([-166, -204, -242, ...,  -23,  -20,  -14], dtype=int16),
#          array([19, 20, 21, ..., 28, 21, 15], dtype=int16),
#          array([-23, -24, -25, ..., -42, -24,   0], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([11624,  9000,  9000, 10168])),
#  (array([array([354, 433, 508, ..., -94, -83, -65], dtype=int16),
#          array([-212, -246, -288, ...,   57,   54,   49], dtype=int16),
#          array([-85, -91, -97, ..., -32, -25, -20], dtype=int16),
#          array([-355, -411, -447, ...,   17,   17,   14], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([277, 334, 382, ...,  83,  59,  37], dtype=int16),
#          array([40, 52, 65, ..., 29, 30, 31], dtype=int16),
#          array([-311, -372, -441, ...,  -42,  -36,  -30], dtype=int16),
#          array([ 21,  23,  33, ..., 218, 177, 137], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([13818,  9000,  9000,  9000])),
#  (array([array([ -816,  -978, -1138, ...,    75,    73,    61], dtype=int16),
#          array([-561, -673, -793, ...,    1,    3,    5], dtype=int16),
#          array([569, 692, 813, ..., -36,   0,   0], dtype=int16),
#          array([249, 315, 390, ...,  33,  24,  15], dtype=int16)], dtype=object),
#   array([1, 0, 0, 2]),
#   array([ 5364, 18000,  9000,  9000])),
#  (array([array([-114, -145, -176, ...,  -85,  -67,  -50], dtype=int16),
#          array([12, 13, 14, ...,  6,  0, -1], dtype=int16),
#          array([61, 65, 63, ..., 49, 47, 44], dtype=int16),
#          array([-281, -342, -396, ...,    9,   -2,  -14], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([ 9000,  9000,  9000, 18000])),
#  (array([array([523, 627, 735, ...,   0,   0,   0], dtype=int16),
#          array([-187, -223, -262, ...,   80,   67,   58], dtype=int16),
#          array([275, 335, 397, ...,  44,  34,  19], dtype=int16),
#          array([-64, -64, -64, ..., -50, -48, -47], dtype=int16)], dtype=object),
#   array([1, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -29,  -53,  -66, ..., -400, -323, -225], dtype=int16),
#          array([ 50,  61,  66, ..., 104,  91,  79], dtype=int16),
#          array([ 814,  947, 1094, ...,  -13,    1,    6], dtype=int16),
#          array([-23, -48, -69, ..., -43, -34, -26], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([343, 416, 494, ...,  -7,  -6,  -6], dtype=int16),
#          array([823, 741, 575, ...,  -3,  -1,   0], dtype=int16),
#          array([  20,   26,   47, ..., -112,  -92,  -67], dtype=int16),
#          array([112, 127, 140, ..., -33, -28, -26], dtype=int16)], dtype=object),
#   array([2, 1, 0, 0]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([ -74,  -88, -101, ..., -178, -194, -165], dtype=int16),
#          array([20, 20, 17, ...,  2,  2,  1], dtype=int16),
#          array([195, 229, 263, ...,  49,  11, -10], dtype=int16),
#          array([-55, -77, -91, ..., -38, -39, -40], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([11686,  9000, 18000,  9000])),
#  (array([array([582, 689, 799, ..., -15,  -2,   6], dtype=int16),
#          array([-20, -23, -27, ...,  44,  48,  48], dtype=int16),
#          array([ 146,  176,  206, ..., -109, -109, -106], dtype=int16),
#          array([-198, -266, -330, ...,   19,   19,   18], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([18000,  9000,  4186,  9000])),
#  (array([array([ -65,  -91, -108, ...,  132,  124,   97], dtype=int16),
#          array([ 77,  97, 118, ...,  25,  34,  36], dtype=int16),
#          array([11, 12, 13, ..., 16, 13, 11], dtype=int16),
#          array([-267, -321, -378, ...,  -15,  -16,  -16], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([13078, 18000,  9000, 18000])),
#  (array([array([ 53,  55,  58, ..., -38, -39, -39], dtype=int16),
#          array([-143, -172, -198, ...,   18,   11,    7], dtype=int16),
#          array([ 744,  882, 1022, ...,  -52,  -64,  -80], dtype=int16),
#          array([ 14,  16,  17, ..., 279, 226, 136], dtype=int16)], dtype=object),
#   array([0, 1, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-450, -540, -626, ...,   17,   18,   19], dtype=int16),
#          array([-66, -73, -79, ..., -94, -85, -74], dtype=int16),
#          array([-47, -65, -81, ..., 412, 415, 339], dtype=int16),
#          array([-160, -196, -232, ...,  -65,  -49,  -32], dtype=int16)], dtype=object),
#   array([1, 0, 0, 1]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-30, -41, -48, ..., 530, 407, 291], dtype=int16),
#          array([505, 607, 712, ..., -41, -32, -24], dtype=int16),
#          array([-720, -851, -988, ...,   30,   23,   17], dtype=int16),
#          array([15, 17, 20, ..., 39, 29, 18], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([ 9000,  9000,  9000, 16316])),
#  (array([array([37, 36, 35, ...,  6, 13, 24], dtype=int16),
#          array([-10, -12, -14, ..., -18, -16, -14], dtype=int16),
#          array([-320, -386, -454, ...,  -43,  -27,  -14], dtype=int16),
#          array([ 0, -2, -3, ...,  4,  4,  5], dtype=int16)], dtype=object),
#   array([2, 2, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([  2,   3,   3, ..., -29, -26, -23], dtype=int16),
#          array([165, 187, 203, ...,   3,   3,   4], dtype=int16),
#          array([-10, -12, -14, ...,  96,  -6, -46], dtype=int16),
#          array([-35, -27,  -4, ...,  67,  55,  42], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([9000, 9000, 9000, 6166])),
#  (array([array([-601, -713, -828, ...,   -9,   -3,    0], dtype=int16),
#          array([-390, -467, -539, ..., -132, -104,  -79], dtype=int16),
#          array([ 52,  73,  93, ..., -33, -26, -14], dtype=int16),
#          array([713, 860, 999, ..., -22, -27, -33], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([ 89, 107, 126, ...,  72,  59,  33], dtype=int16),
#          array([122, 147, 176, ..., -39, -39, -38], dtype=int16),
#          array([ -89, -107, -117, ...,  -20,  -15,   -8], dtype=int16),
#          array([-171, -204, -253, ...,  -45,  -30,  -18], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([ 9000,  9000, 10414,  9000])),
#  (array([array([ 29,  31,  34, ..., -15, -12, -10], dtype=int16),
#          array([ -843, -1000, -1130, ...,   200,   165,   103], dtype=int16),
#          array([ 85, 113, 145, ...,  83,  72,  48], dtype=int16),
#          array([-233, -287, -337, ..., -127, -101,  -78], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 4004, 6326])),
#  (array([array([ -8,  -8,  -8, ..., -89, -74, -55], dtype=int16),
#          array([ 200,  249,  299, ..., -296, -205, -124], dtype=int16),
#          array([668, 809, 956, ...,   9,  10,  10], dtype=int16),
#          array([218, 271, 306, ...,  11,  10,   9], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-448, -544, -641, ...,  -16,  -25,  -32], dtype=int16),
#          array([516, 621, 732, ...,  10,   9,   8], dtype=int16),
#          array([-190, -236, -286, ...,  158,   91,    8], dtype=int16),
#          array([-12, -12, -12, ..., -19, -20, -21], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([3472, 9000, 3338, 9000])),
#  (array([array([-33, -61, -74, ..., -18, -19, -19], dtype=int16),
#          array([ 36,  48,  58, ..., -12, -11, -11], dtype=int16),
#          array([40, 55, 60, ..., -2,  5, 13], dtype=int16),
#          array([-364, -448, -535, ...,  -39,  -30,  -21], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([ 9996,  9000, 10840,  9000])),
#  (array([array([253, 272, 280, ...,  -4,  -2,   0], dtype=int16),
#          array([450, 530, 615, ..., 170, 129,  89], dtype=int16),
#          array([-323, -385, -453, ...,  -75,  -68,  -58], dtype=int16),
#          array([-161, -195, -228, ...,  264,  218,  174], dtype=int16)], dtype=object),
#   array([2, 2, 2, 2]),
#   array([14264,  9000,  9000,  9000])),
#  (array([array([-108, -131, -147, ...,   74,   59,   37], dtype=int16),
#          array([-533, -646, -745, ..., -109,  -97,  -82], dtype=int16),
#          array([-49, -52, -55, ...,  19,  14,   4], dtype=int16),
#          array([ 14,  18,  25, ..., -35, -30, -28], dtype=int16)], dtype=object),
#   array([0, 2, 1, 2]),
#   array([ 9000,  9000,  4492, 11280])),
#  (array([array([ 54,  60,  66, ..., -24, -19, -18], dtype=int16),
#          array([211, 177, 145, ...,  58,  55,  52], dtype=int16),
#          array([-163, -189, -204, ...,  -68,  -48,  -32], dtype=int16),
#          array([121, 151, 172, ...,  51,  40,  29], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-45, -61, -74, ...,   5,   7,   8], dtype=int16),
#          array([306, 365, 421, ...,  -5,  -6,  -7], dtype=int16),
#          array([-26, -41, -55, ...,  54,  43,  36], dtype=int16),
#          array([-146, -269, -422, ...,  112,   98,   83], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([ 5022,  9000,  9000, 18000])),
#  (array([array([-78, -66, -50, ..., -63, -64, -64], dtype=int16),
#          array([-12, -14, -15, ..., -87, -66, -45], dtype=int16),
#          array([-27,  29, 128, ...,  37,  39,  74], dtype=int16),
#          array([-50, -67, -80, ..., 300,  69, -24], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 90, 110, 123, ...,   6,   6,   6], dtype=int16),
#          array([ -73,  -71,  -69, ..., -198, -184, -166], dtype=int16),
#          array([ 461,  546,  608, ..., -106,  -58,  -24], dtype=int16),
#          array([ 43,  46,  65, ..., -68, -55, -58], dtype=int16)], dtype=object),
#   array([0, 2, 3, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-1078, -1304, -1533, ...,   -60,   -57,   -51], dtype=int16),
#          array([-1072, -1282, -1492, ...,    -3,    -1,     0], dtype=int16),
#          array([-667, -792, -925, ...,   87,   81,   74], dtype=int16),
#          array([-120, -146, -172, ..., -190,  -72,   73], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -13,  -13,  -13, ..., -105, -104, -104], dtype=int16),
#          array([  6,   8,   9, ..., -67, -20,  21], dtype=int16),
#          array([115,  94,  68, ...,  39,  40,  41], dtype=int16),
#          array([426, 444, 433, ...,  -9,  -8,  -6], dtype=int16)], dtype=object),
#   array([2, 0, 2, 0]),
#   array([ 9000, 13688,  9000,  9000])),
#  (array([array([ 440,  519,  601, ..., -116,  -78,  -41], dtype=int16),
#          array([-150, -178, -208, ..., -111,  -86,  -61], dtype=int16),
#          array([374, 487, 631, ..., -46, -41, -36], dtype=int16),
#          array([-228, -279, -329, ...,   18,   16,   14], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([74, 74, 73, ..., 94, 95, 95], dtype=int16),
#          array([ 744,  884, 1027, ..., -322, -216, -126], dtype=int16),
#          array([311, 368, 423, ..., -61, -45, -30], dtype=int16),
#          array([-250, -295, -338, ...,  -12,  -11,   -9], dtype=int16)], dtype=object),
#   array([2, 2, 2, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-118, -117, -116, ...,  -11,   -9,   -7], dtype=int16),
#          array([675, 816, 951, ...,  13,   9,   5], dtype=int16),
#          array([  73,   94,  114, ..., -227, -174, -137], dtype=int16),
#          array([147, 130, 113, ..., -29, -26, -24], dtype=int16)], dtype=object),
#   array([2, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([385, 461, 542, ...,  -6,  -6,  -7], dtype=int16),
#          array([494, 596, 702, ...,  25,  15,   5], dtype=int16),
#          array([677, 819, 966, ...,  91,  71,  40], dtype=int16),
#          array([575, 682, 781, ...,  51,  39,  28], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([18000,  9000,  4898,  9000])),
#  (array([array([ -90, -110, -129, ...,  304,  119,   28], dtype=int16),
#          array([-72, -77, -80, ..., 207, 181, 138], dtype=int16),
#          array([263, 323, 385, ...,  10,   4,   0], dtype=int16),
#          array([-27, -26,  -9, ...,  30,  27,  25], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 9000, 3748])),
#  (array([array([-62, -72, -81, ..., -70, -66, -62], dtype=int16),
#          array([-58, -74, -84, ..., 120, 104,  73], dtype=int16),
#          array([ -37,  -35,  -33, ..., -113, -108, -102], dtype=int16),
#          array([ 776,  919, 1080, ...,   -5,    6,   18], dtype=int16)], dtype=object),
#   array([0, 2, 0, 1]),
#   array([5570, 3900, 9000, 3264])),
#  (array([array([-130, -163, -227, ...,  -13,  -12,  -11], dtype=int16),
#          array([ 141,  228,  334, ..., 1425, 1156,  699], dtype=int16),
#          array([-607, -728, -845, ..., -212, -196, -153], dtype=int16),
#          array([177, 208, 242, ..., -16, -10,  -4], dtype=int16)], dtype=object),
#   array([0, 1, 0, 0]),
#   array([9000, 4080, 7240, 9000])),
#  (array([array([52, 71, 86, ..., 30, 19,  3], dtype=int16),
#          array([ -66,  -83, -101, ...,  -29,  -24,  -18], dtype=int16),
#          array([111, 139, 171, ..., 467, 335, 218], dtype=int16),
#          array([-58, -71, -79, ...,  31,  30,  29], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 9000, 4512, 9000])),
#  (array([array([ 78,  87,  95, ..., -32, -29, -26], dtype=int16),
#          array([518, 634, 749, ...,  35,  26,  16], dtype=int16),
#          array([15, 16, 18, ..., 93, 75, 57], dtype=int16),
#          array([  53,   61,   68, ..., -214, -167,   -4], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([225, 212, 169, ...,  40,  27,  15], dtype=int16),
#          array([ 64,  74,  81, ...,  76,  25, -27], dtype=int16),
#          array([-302, -363, -429, ...,  -20,  -10,   -2], dtype=int16),
#          array([30, 34, 41, ..., -3, -2, -1], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 9000, 3972])),
#  (array([array([ 28,  30,  32, ..., -22, -22, -22], dtype=int16),
#          array([ 7,  8,  9, ..., 11,  8,  7], dtype=int16),
#          array([-33, -32, -29, ..., 184, 250, 330], dtype=int16),
#          array([  95,  112,  130, ..., -126, -120, -111], dtype=int16)], dtype=object),
#   array([1, 0, 2, 1]),
#   array([9000, 9000, 9000, 4326])),
#  (array([array([-106, -133, -157, ...,   34,   26,   21], dtype=int16),
#          array([-494, -603, -707, ...,   -8,   11,   18], dtype=int16),
#          array([15, 17, 17, ..., 86, 87, 88], dtype=int16),
#          array([-45, -65, -86, ..., 181, 164, 134], dtype=int16)], dtype=object),
#   array([0, 0, 2, 2]),
#   array([11062,  9000,  9000,  9000])),
#  (array([array([-315, -376, -425, ...,    5,    4,    2], dtype=int16),
#          array([ 50,  66,  83, ..., -48, -48, -48], dtype=int16),
#          array([305, 357, 410, ...,  76,  68,  54], dtype=int16),
#          array([-35, -73, -97, ...,   0,  -1,  -2], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([18182, 18000,  9000,  9000])),
# ...
#  (array([array([706, 842, 980, ...,  -9,  -9,  -8], dtype=int16),
#          array([ 77,  91, 104, ...,  15,  14,  13], dtype=int16),
#          array([-218, -275, -338, ...,  -66,  -59,  -50], dtype=int16),
#          array([13, 14, 17, ..., 48, 42, 34], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9592, 8090, 9000, 9000])),
#  (array([array([54, 70, 87, ...,  3,  3,  2], dtype=int16),
#          array([20, 34, 71, ..., 34, 28, 22], dtype=int16),
#          array([ 183,  219,  255, ..., -270, -229, -183], dtype=int16),
#          array([231, 260, 290, ...,  39,  35,  28], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 7200, 3100, 9000])),
#  (array([array([ 80,  97, 113, ...,  87,  62,  45], dtype=int16),
#          array([-221, -256, -295, ...,  -76,  -53,  -30], dtype=int16),
#          array([-661, -786, -918, ...,  -10,  -10,  -10], dtype=int16),
#          array([  3,   5,   6, ..., -10,  -1,   3], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([427, 506, 592, ...,   0,   0,  -1], dtype=int16),
#          array([-249, -307, -368, ...,  -49,  -24,    1], dtype=int16),
#          array([-102, -112, -120, ...,   71,   54,   37], dtype=int16),
#          array([16, 17, 18, ..., 32, 23, 14], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([268, 325, 387, ...,   8,   9,   9], dtype=int16),
#          array([291, 345, 405, ..., -27, -27, -26], dtype=int16),
#          array([-312, -385, -457, ..., -251, -212, -172], dtype=int16),
#          array([168, 206, 226, ..., -37, -23, -12], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 9000, 9000, 3566])),
#  (array([array([-231, -274, -319, ...,  -40,  -34,  -22], dtype=int16),
#          array([-156, -205, -240, ...,  -45,  -34,  -23], dtype=int16),
#          array([-135, -160, -178, ...,  -20,  -19,  -19], dtype=int16),
#          array([ 276,  334,  394, ..., -142, -117,  -96], dtype=int16)], dtype=object),
#   array([2, 0, 0, 2]),
#   array([18000,  9000,  9000,  9000])),
#  (array([array([-193, -221, -250, ...,   75,   60,   44], dtype=int16),
#          array([-120, -146, -173, ...,   89,   78,   64], dtype=int16),
#          array([-154, -188, -222, ...,   49,   41,   34], dtype=int16),
#          array([411, 495, 579, ..., -62, -57, -46], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([50, 69, 85, ..., 56, 42, 31], dtype=int16),
#          array([16, 22, 30, ..., 41, 27, 16], dtype=int16),
#          array([-24, -44, -60, ...,   3,   3,   2], dtype=int16),
#          array([ 34,  32,  30, ..., -45, -50, -52], dtype=int16)], dtype=object),
#   array([0, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-111, -111, -110, ...,  -35,  -39,  -43], dtype=int16),
#          array([-110, -128, -152, ...,    0,  -17,  -24], dtype=int16),
#          array([ -89, -110, -137, ...,  123,   94,   69], dtype=int16),
#          array([-115, -154, -193, ...,   -3,    0,    2], dtype=int16)], dtype=object),
#   array([2, 2, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([642, 773, 900, ...,   8,   9,   9], dtype=int16),
#          array([-262, -314, -365, ...,  139,  112,   86], dtype=int16),
#          array([105, 199, 321, ..., -90, -75, -56], dtype=int16),
#          array([-120, -142, -171, ...,  -27,  -24,  -22], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([  1,   2,   3, ..., -18, -11,  -9], dtype=int16),
#          array([565, 675, 790, ..., -17, -14, -13], dtype=int16),
#          array([ -902, -1088, -1278, ...,    22,    21,    20], dtype=int16),
#          array([-232, -278, -330, ...,   -7,   -8,   -8], dtype=int16)], dtype=object),
#   array([1, 2, 0, 2]),
#   array([ 9000, 18000,  9000,  9000])),
#  (array([array([337, 410, 487, ...,  77,  56,  41], dtype=int16),
#          array([ 77,  99, 120, ..., 505, 311, 180], dtype=int16),
#          array([257, 308, 362, ...,  85,  70,  62], dtype=int16),
#          array([ -13,  -14,  -16, ..., -892, -618, -443], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([18000,  5084,  9000,  6094])),
#  (array([array([157, 187, 221, ..., -10,  -4,   0], dtype=int16),
#          array([-395, -468, -543, ...,   30,   30,   30], dtype=int16),
#          array([-120, -146, -181, ...,   86,   66,   48], dtype=int16),
#          array([385, 446, 467, ...,  85,  69,  54], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([443, 533, 628, ..., 268, 179,  47], dtype=int16),
#          array([-60, -73, -80, ...,  -7,  -7,  -5], dtype=int16),
#          array([120, 149, 177, ..., 149, 122,  86], dtype=int16),
#          array([35, 39, 44, ..., -3, -4, -5], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([18000,  9000,  3536, 18000])),
#  (array([array([-39, -56, -67, ..., -55, -44, -29], dtype=int16),
#          array([-11, -13, -26, ..., 165, 173, 161], dtype=int16),
#          array([-126, -141, -152, ...,  -56,  -47,  -36], dtype=int16),
#          array([14, 14, 19, ..., 32, 25, 19], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9856, 9000, 9000])),
#  (array([array([268, 328, 388, ..., 499, 407, 318], dtype=int16),
#          array([ -77, -123, -172, ...,   54,    9,  -40], dtype=int16),
#          array([574, 683, 794, ..., -10,  -8,  -7], dtype=int16),
#          array([-325, -392, -462, ...,  -37,  -33,  -27], dtype=int16)], dtype=object),
#   array([2, 0, 0, 1]),
#   array([9000, 9000, 9000, 8836])),
#  (array([array([204, 248, 297, ..., -26, -21, -15], dtype=int16),
#          array([334, 395, 454, ..., 128, 125, 111], dtype=int16),
#          array([-121, -197, -288, ...,  -96,  -77,  -59], dtype=int16),
#          array([60, 65, 70, ..., 30, 27, 24], dtype=int16)], dtype=object),
#   array([2, 0, 2, 1]),
#   array([ 4040,  9000,  9000, 18000])),
#  (array([array([-193, -239, -290, ..., -119,  -87,  -55], dtype=int16),
#          array([ 25,  45,  59, ..., -44, -42, -33], dtype=int16),
#          array([374, 452, 527, ..., 104,  66,  31], dtype=int16),
#          array([143, 167, 197, ...,  86,  76,  62], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([6878, 9000, 5948, 9000])),
#  (array([array([ 98, 126, 155, ..., -36, -38, -39], dtype=int16),
#          array([-486, -575, -670, ...,  -78,  -66,  -50], dtype=int16),
#          array([-2, -2, -2, ...,  4,  4,  3], dtype=int16),
#          array([ -25,  -37,  -50, ..., -314, -262, -217], dtype=int16)], dtype=object),
#   array([0, 1, 2, 0]),
#   array([ 9000,  9000,  9000, 13398])),
#  (array([array([259, 309, 359, ...,  42,  25,  19], dtype=int16),
#          array([125, 175, 222, ...,  30,  33,  35], dtype=int16),
#          array([ 80,  93, 106, ...,  47,  69,  76], dtype=int16),
#          array([  18,   11,  -26, ..., -856, -890, -871], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 3194, 3776, 9000])),
#  (array([array([-412, -488, -566, ...,  -15,   -7,    1], dtype=int16),
#          array([ -4,  -5,  -6, ..., -38, -41, -43], dtype=int16),
#          array([257, 305, 362, ..., -79, -72, -64], dtype=int16),
#          array([141, 201, 221, ..., -58, -24, -12], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([18000, 18000,  9000,  9000])),
#  (array([array([-508, -612, -719, ..., -312, -227, -124], dtype=int16),
#          array([-554, -688, -837, ...,   11,   13,   14], dtype=int16),
#          array([126, 156, 175, ..., 463, 396, 338], dtype=int16),
#          array([-71, -84, -96, ..., -87, -82, -79], dtype=int16)], dtype=object),
#   array([0, 1, 0, 0]),
#   array([3166, 9000, 9000, 9000])),
#  (array([array([  2,   2,   3, ..., -19, -18, -13], dtype=int16),
#          array([-55, -62, -65, ..., -89, -79, -65], dtype=int16),
#          array([169, 203, 239, ..., -23, -15, -10], dtype=int16),
#          array([-173, -205, -243, ...,    0,    0,    0], dtype=int16)], dtype=object),
#   array([2, 2, 1, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([-525, -629, -739, ...,  -41,  -41,  -41], dtype=int16),
#          array([-268, -314, -335, ...,  -44,  -29,  -17], dtype=int16),
#          array([-437, -523, -622, ...,  384,  372,  279], dtype=int16),
#          array([51, 59, 62, ..., 22, 23, 21], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([18000, 12068, 18000, 14104])),
#  (array([array([28, 30, 32, ..., 31, 32, 33], dtype=int16),
#          array([-237, -285, -337, ...,  -78,  -57,  -37], dtype=int16),
#          array([166, 199, 234, ...,   0,  19,  33], dtype=int16),
#          array([ 573,  684,  803, ..., -634, -524, -426], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([9000, 9000, 9000, 5282])),
#  (array([array([ 23,  25,  27, ..., -20, -11,  -5], dtype=int16),
#          array([ 843,  997, 1144, ...,  -13,   -4,    1], dtype=int16),
#          array([-23, -30, -38, ...,  72,  93, 102], dtype=int16),
#          array([ 342,  410,  480, ..., -582, -488, -325], dtype=int16)], dtype=object),
#   array([2, 2, 0, 0]),
#   array([ 9000,  9000, 10362,  9000])),
#  (array([array([-343, -355, -363, ...,  -47,  -36,  -27], dtype=int16),
#          array([-141, -161, -178, ...,   32,   41,   45], dtype=int16),
#          array([10, 11, 12, ..., 39, 38, 35], dtype=int16),
#          array([ 114,  151,  192, ..., -124,  -88,  -51], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([ 9000, 18062,  9000,  9000])),
#  (array([array([66, 67, 69, ..., 62, 62, 61], dtype=int16),
#          array([-251, -305, -362, ...,  104,   80,   54], dtype=int16),
#          array([308, 370, 434, ...,  59,  48,  34], dtype=int16),
#          array([482, 579, 680, ..., 117,  71,  25], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -5,  -7,  -8, ..., -99, -78, -58], dtype=int16),
#          array([194, 244, 296, ..., 148,  85,   9], dtype=int16),
#          array([101, 128, 151, ...,   3,   3,   3], dtype=int16),
#          array([   8,   10,   12, ..., -294, -272, -243], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([ 9000, 18188,  9000,  9000])),
#  (array([array([-17, -18, -20, ...,  25,   4,   4], dtype=int16),
#          array([-138, -168, -201, ..., 1233,  916,  595], dtype=int16),
#          array([ -58,  -71,  -79, ..., -255, -223, -189], dtype=int16),
#          array([-216, -269, -324, ...,  -25,  -18,  -12], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([ 9000,  9000, 18000,  9000])),
#  (array([array([ -66,  -84, -102, ...,   43,   30,   16], dtype=int16),
#          array([-167, -189, -209, ..., -109,  -89,  -74], dtype=int16),
#          array([-19, -19, -19, ..., -27, -26, -24], dtype=int16),
#          array([-32, -44, -46, ..., 218, 200, 132], dtype=int16)], dtype=object),
#   array([0, 0, 0, 2]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 38,  79, 110, ...,  -2,  -1,   0], dtype=int16),
#          array([ 942, 1084, 1198, ...,  -13,   -8,   -4], dtype=int16),
#          array([378, 462, 533, ..., -97, -43,  14], dtype=int16),
#          array([123, 145, 161, ..., -14,  19,  51], dtype=int16)], dtype=object),
#   array([2, 2, 2, 0]),
#   array([14568, 12116, 10486,  9000])),
#  (array([array([  96,  116,  136, ...,  -90,  -98, -105], dtype=int16),
#          array([13, 13, 12, ..., 24, 24, 23], dtype=int16),
#          array([703, 832, 957, ..., 183, 156, 128], dtype=int16),
#          array([454, 545, 641, ..., -65, -58, -48], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([ 9000,  7284, 18000, 18000])),
#  (array([array([-38, -52, -64, ..., 150, 169, 200], dtype=int16),
#          array([-16, -29, -42, ..., -55, -41, -27], dtype=int16),
#          array([391, 465, 578, ...,  33,  12,   3], dtype=int16),
#          array([ 53,  73,  91, ..., -67, -34,   5], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([ 9000, 18000,  9000, 18000])),
#  (array([array([  6,   5,   5, ..., -19, -16, -15], dtype=int16),
#          array([-274, -333, -400, ...,   32,   27,   21], dtype=int16),
#          array([21, 26, 45, ..., 32, 35, 38], dtype=int16),
#          array([218, 249, 299, ..., -40, -39, -39], dtype=int16)], dtype=object),
#   array([2, 0, 2, 0]),
#   array([9000, 9000, 9968, 9000])),
#  (array([array([-210, -263, -314, ...,  317,  195,   51], dtype=int16),
#          array([ -21,  -25,  -29, ..., -483, -453, -438], dtype=int16),
#          array([ 16,  15,  14, ..., 133, 182, 223], dtype=int16),
#          array([547, 625, 696, ..., -14, -11,  -7], dtype=int16)], dtype=object),
#   array([0, 2, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([452, 548, 647, ...,  43,  29,  16], dtype=int16),
#          array([ -46,  -52,  -54, ..., -224, -135,  -14], dtype=int16),
#          array([-41, -48, -54, ..., -81, -41,  -2], dtype=int16),
#          array([-26, -32, -25, ...,  48,  41,  36], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([9000, 9000, 4544, 9000])),
#  (array([array([-159, -189, -238, ..., -165, -137, -109], dtype=int16),
#          array([-83, -83, -83, ...,  10,  10,  10], dtype=int16),
#          array([509, 593, 683, ..., -50, -41, -31], dtype=int16),
#          array([148, 193, 242, ...,  72,  75,  65], dtype=int16)], dtype=object),
#   array([2, 0, 2, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -17,  -19,  -20, ..., -153, -109,  -67], dtype=int16),
#          array([  2,   1,   1, ..., -18, -14, -11], dtype=int16),
#          array([ -52,  -87, -117, ...,  195,  190,  148], dtype=int16),
#          array([-47, -52, -51, ...,   3,   3,   3], dtype=int16)], dtype=object),
#   array([0, 2, 0, 2]),
#   array([ 9980,  9000,  9000, 18000])),
#  (array([array([ 17,  21,  24, ..., -14,   0,  15], dtype=int16),
#          array([216, 263, 310, ...,  13,  11,   9], dtype=int16),
#          array([-278, -331, -398, ...,   -8,   -7,   -5], dtype=int16),
#          array([207, 236, 284, ..., 230, 214, 187], dtype=int16)], dtype=object),
#   array([0, 0, 1, 0]),
#   array([3962, 4838, 9000, 5912])),
#  (array([array([-290, -350, -412, ...,  -57,  -46,  -37], dtype=int16),
#          array([ 83,  97, 109, ..., 232, 163, 105], dtype=int16),
#          array([76, 60, 36, ..., 51, 49, 44], dtype=int16),
#          array([132, 168, 206, ..., -12,  -2,   6], dtype=int16)], dtype=object),
#   array([0, 0, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ -69,  -93, -110, ...,  -40,  -23,   -6], dtype=int16),
#          array([308, 368, 429, ...,  62,  -9, -19], dtype=int16),
#          array([115, 143, 175, ..., -43, -38, -31], dtype=int16),
#          array([-125, -158, -188, ...,  -74,  -58,  -47], dtype=int16)], dtype=object),
#   array([0, 1, 1, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([ 14,  13,  13, ..., -96, -74, -58], dtype=int16),
#          array([517, 618, 712, ..., -41, -26, -11], dtype=int16),
#          array([342, 413, 492, ..., -17, -14, -13], dtype=int16),
#          array([474, 578, 679, ...,  70,  31,   0], dtype=int16)], dtype=object),
#   array([2, 0, 0, 0]),
#   array([10334, 15266,  9000,  7446])),
#  (array([array([ 96, 116, 128, ...,  58,  42,  26], dtype=int16),
#          array([392, 470, 552, ...,  -6,  -3,   0], dtype=int16),
#          array([445, 538, 628, ...,  20,  21,  22], dtype=int16),
#          array([282, 337, 399, ...,  26,  24,  22], dtype=int16)], dtype=object),
#   array([0, 2, 0, 0]),
#   array([9000, 9000, 9000, 9000])),
#  (array([array([308, 377, 451, ...,  65,  60,  54], dtype=int16),
#          array([ 30,  32,  34, ..., -60, -45, -31], dtype=int16),
#          array([-476, -580, -689, ...,  -18,  -12,   -8], dtype=int16),
#          array([ 21,  22,  23, ..., -14, -13, -13], dtype=int16)], dtype=object),
#   array([0, 0, 1, 2]),
#   array([ 6174,  9000, 17826,  9000])),
#  (array([array([-219, -254, -295, ...,   -6,    8,   20], dtype=int16),
#          array([ 6,  6,  5, ..., 21, 24, 26], dtype=int16),
#          array([ 591,  711,  838, ..., -143, -107,  -69], dtype=int16),
#          array([ 467,  556,  650, ..., -266, -203, -134], dtype=int16)], dtype=object),
#   array([0, 0, 0, 1]),
#   array([9000, 9000, 9000, 9000])),
#  ...]
