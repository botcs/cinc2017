# %%
import json
import os
import numpy as np
import tensorflow as tf
from model.assembler import get_model_logits

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from model import train_ops
from model import summary_ops
import data.ops

# %matplotlib inline

sns.set_style('white')
sns.set_context('poster')
plt.rc("axes.spines", top=False, right=False, left=False, bottom=False)
plt.rcParams['figure.figsize'] = (10.0, 2)
proto_path = './test_scripts/deep_resnet.json'
proto_name = os.path.splitext(proto_path)[0]
proto_name = os.path.basename(proto_name)

# %%
tf.reset_default_graph()
network_params = json.load(open(proto_path))
#input_op = tf.placeholder(tf.float32, [None, None], 'INPUT')
#label_op = tf.placeholder(tf.int32, [None], 'LABEL')
bsize = tf.placeholder_with_default(2, [], 'batch_size')
input_op, seq_len, label_op = data.ops.get_batch_producer(
    './data/TFRecords/aug_train.TFRecord', bsize)


# for debug!!!
summary_ops.add_label_hist(label_op)
logits = get_model_logits(seq_len, input_op, **network_params)

t_ops = train_ops.get_trainer(label_op, logits)
step, train, loss, conf, acc, lrate, loss_avg, ver_avg = t_ops

tf.summary.histogram('sample_diversity', label_op)
s_op = summary_ops.get_all_summaries(*t_ops)
sv = tf.train.Supervisor(
    logdir='/tmp/csbotos_onlab/%s/' % proto_name, summary_op=s_op,
)
# Out:
# Tensor("ResNet/FCN_block_0/Conv0/conv1d/Squeeze:0", shape=(?, ?, 8), dtype=float32)
# Tensor("ResNet/FCN_block_0/Conv1/conv1d/Squeeze:0", shape=(?, ?, 16), dtype=float32)
# Tensor("ResNet/FCN_block_0/Conv2/conv1d/Squeeze:0", shape=(?, ?, 16), dtype=float32)
#
# Tensor("ResNet/FCN_block_1/Conv0/conv1d/Squeeze:0", shape=(?, ?, 32), dtype=float32)
# Tensor("ResNet/FCN_block_1/Conv1/conv1d/Squeeze:0", shape=(?, ?, 32), dtype=float32)
#
# Tensor("ResNet/FCN_block_2/Conv0/conv1d/Squeeze:0", shape=(?, ?, 32), dtype=float32)
# Tensor("ResNet/FCN_block_2/Conv1/conv1d/Squeeze:0", shape=(?, ?, 64), dtype=float32)
# Tensor("ResNet/FCN_block_2/Conv2/conv1d/Squeeze:0", shape=(?, ?, 64), dtype=float32)
#
# Tensor("ResNet/FCN_block_3/Conv0/conv1d/Squeeze:0", shape=(?, ?, 64), dtype=float32)
# Tensor("ResNet/FCN_block_3/Conv1/conv1d/Squeeze:0", shape=(?, ?, 128), dtype=float32)
# Tensor("ResNet/FCN_block_3/Conv2/conv1d/Squeeze:0", shape=(?, ?, 128), dtype=float32)
#
# Tensor("ResNet/FCN_block_4/Conv0/conv1d/Squeeze:0", shape=(?, ?, 128), dtype=float32)
# Tensor("ResNet/FCN_block_4/Conv1/conv1d/Squeeze:0", shape=(?, ?, 128), dtype=float32)
#
# Variable sized windowing -- number of windows: 5
#   Dimensions: [batch_size, num_windows, window_size, num_features]
# Tensor("sample_division/Reshape:0", shape=(?, 5, ?, 128), dtype=float32)
# Local reduce:
# Tensor("Mean:0", shape=(?, 5, 128), dtype=float32)
#
# FC--fc
# Tensor("classifier/batch_normalization/cond/Merge:0", shape=(?, 4), dtype=float32)
# Tensor("classifier/predictions:0", shape=(?, 4), dtype=float32)

# %%
with sv.managed_session() as sess:
    #print(sess.run(step))
    weight_vars = tf.get_collection('weights')
    weight_vals = sess.run(weight_vars)
    #input_val = sess.run(input_op)
    features = tf.get_collection('activations')[-3]
    features_val = sess.run(features, {input_op:input_val})
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/csbotos_onlab/deep_resnet/model.ckpt-8194
# INFO:tensorflow:global_step/sec: 0

# %%
plt.figure(figsize=(10, 2))
plt.plot(input_val[1, 6000:8000], color='black')
sns.despine(None, None, *[True] * 4)

# %%
from scipy import signal
window = signal.gaussian(1000, 150)
plt.figure(figsize=(5, 5))

plt.axis('off')
sin = np.sin(np.linspace(-4, 4, 1000)*5) * 0.1
plt.plot(window*sin, color='black')

# %%
plt.plot(np.convolve(input_val[1, 6000:8000], window*sin))

# %%
#plt.bar(features_val[1, :, 0] - features_val[1, :, 3], 'black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-c80309a27858> in <module>()
# ----> 1 plt.bar(features_val[1, :, 0] - features_val[1, :, 3], 'black')
#
# /usr/lib64/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2648     try:
#    2649         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2650                      **kwargs)
#    2651     finally:
#    2652         ax.hold(washold)
#
# /usr/lib64/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /usr/lib64/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2036         if len(height) != nbars:
#    2037             raise ValueError("incompatible sizes: argument 'height' "
# -> 2038                               "must be length %d or scalar" % nbars)
#    2039         if len(width) != nbars:
#    2040             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 281 or scalar

# %%
for f in features_val[1, :, :100].T:
    #plt.plot(input_val[0])
    #plt.show()
    plt.figure(figsize=(10, 2))
    plt.plot(f, 'red')
    plt.axis('off')
    sns.despine(None, None, *[True] * 4)
    plt.show()

# %%
for i, v in enumerate(weight_vars):
    print(i, v.op.name, v.shape)
# Out:
# 0 ResNet/FCN_block_0/Conv0/weights (128, 1, 8)
# 1 ResNet/FCN_block_0/Conv1/weights (128, 8, 16)
# 2 ResNet/FCN_block_0/Conv2/weights (64, 16, 16)
# 3 ResNet/shortcut_connection_0/weights (4, 1, 16)
# 4 ResNet/FCN_block_1/Conv0/weights (32, 16, 32)
# 5 ResNet/FCN_block_1/Conv1/weights (32, 32, 32)
# 6 ResNet/shortcut_connection_1/weights (2, 16, 32)
# 7 ResNet/FCN_block_2/Conv0/weights (1, 32, 32)
# 8 ResNet/FCN_block_2/Conv1/weights (32, 32, 64)
# 9 ResNet/FCN_block_2/Conv2/weights (1, 64, 64)
# 10 ResNet/shortcut_connection_2/weights (2, 32, 64)
# 11 ResNet/FCN_block_3/Conv0/weights (1, 64, 64)
# 12 ResNet/FCN_block_3/Conv1/weights (16, 64, 128)
# 13 ResNet/FCN_block_3/Conv2/weights (1, 128, 128)
# 14 ResNet/shortcut_connection_3/weights (2, 64, 128)
# 15 ResNet/FCN_block_4/Conv0/weights (8, 128, 128)
# 16 ResNet/FCN_block_4/Conv1/weights (8, 128, 128)
# 17 ResNet/shortcut_connection_4/weights (2, 128, 128)
# 18 ResNet/FCN_block_0/Conv0/weights (128, 1, 8)
# 19 ResNet/FCN_block_0/Conv1/weights (128, 8, 16)
# 20 ResNet/FCN_block_0/Conv2/weights (64, 16, 16)
# 21 ResNet/shortcut_connection_0/weights (4, 1, 16)
# 22 ResNet/FCN_block_1/Conv0/weights (32, 16, 32)
# 23 ResNet/FCN_block_1/Conv1/weights (32, 32, 32)
# 24 ResNet/shortcut_connection_1/weights (2, 16, 32)
# 25 ResNet/FCN_block_2/Conv0/weights (1, 32, 32)
# 26 ResNet/FCN_block_2/Conv1/weights (32, 32, 64)
# 27 ResNet/FCN_block_2/Conv2/weights (1, 64, 64)
# 28 ResNet/shortcut_connection_2/weights (2, 32, 64)
# 29 ResNet/FCN_block_3/Conv0/weights (1, 64, 64)
# 30 ResNet/FCN_block_3/Conv1/weights (16, 64, 128)
# 31 ResNet/FCN_block_3/Conv2/weights (1, 128, 128)
# 32 ResNet/shortcut_connection_3/weights (2, 64, 128)
# 33 ResNet/FCN_block_4/Conv0/weights (8, 128, 128)
# 34 ResNet/FCN_block_4/Conv1/weights (8, 128, 128)
# 35 ResNet/shortcut_connection_4/weights (2, 128, 128)
# 36 classifier/logits/weights (640, 4)

# %%
for v in weight_vals[26][:, 0, :10].T:
    plt.plot(v)
    plt.show()

# %% [markdown]
# # Sanity check

# %%
tf.reset_default_graph()
bsize = tf.placeholder_with_default(4, [], 'batch_size')
input_op, seq_len, label_op = data.ops.get_batch_producer(
    './data/TFRecords/aug_train.TFRecord', bsize)

# %%
sv = tf.train.Supervisor(logdir='/tmp/misc')
with sv.managed_session() as sess:
    res = []
    for i in range(10):
        res.append(sess.run(input_op))

# %%
#res
plt.plot(res[0][0].T)
plt.plot(res[1][0])
